# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
max_cities = int(input("Enter the maximum number of cities you want to generate, keep in mind the more cities you generate the longer it will take: "))
if max_cities <= 0:
    print("Invalid input. Please enter a positive integer.")
else:
    print("Generating cities...")
    lat_lngs = []

    # Empty list for holding the latitude and longitude combinations
    lat_lngs = []

    # Empty list for holding the cities names
    cities = []

    # Range of latitudes and longitudes
    lat_range = (-90, 90)
    lng_range = (-180, 180)

    # Create a set of random lat and lng combinations
    lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
    lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
    lat_lngs = zip(lats, lngs)

    # Identify nearest city for each lat, lng combination
    counter = 0
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

        # If the city is unique, then add it to a our cities list
        if city not in cities:
            if counter < max_cities:
                cities.append(city)
                counter += 1
    # Print the city count to confirm sufficient count
    print(f"Number of cities in the list: {len(cities)}")
# Out:
# Generating cities...
# Number of cities in the list: 20

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    def debug():
        # Run an API request for each of the cities
        try:
            # Parse the JSON and retrieve data
            city_weather = requests.get(city_url).json()
            city_weather_json = json.dumps(city_weather, indent=4)

            # Print the beautified JSON
            print(city_weather_json)
            print('here')

            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_date = city_weather["dt"]

            # Append the City information into city_data list
            city_data.append({"City": city,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})
        # If an error is experienced, skip the city
        except:
            print("City not found. Skipping...")
            pass
    debug()

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# {
#     "coord": {
#         "lon": -130.1015,
#         "lat": -25.066
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.29,
#         "feels_like": 295.86,
#         "temp_min": 295.29,
#         "temp_max": 295.29,
#         "pressure": 1016,
#         "humidity": 88,
#         "sea_level": 1016,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.75,
#         "deg": 11,
#         "gust": 15.36
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1721366106,
#     "sys": {
#         "country": "PN",
#         "sunrise": 1721316217,
#         "sunset": 1721354961
#     },
#     "timezone": -28800,
#     "id": 4030723,
#     "name": "Adamstown",
#     "cod": 200
# }
# here
# Processing Record 2 of Set 1 | rehoboth
# {
#     "coord": {
#         "lon": 17.0833,
#         "lat": -23.3167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 278.82,
#         "feels_like": 276.99,
#         "temp_min": 278.82,
#         "temp_max": 278.82,
#         "pressure": 1022,
#         "humidity": 36,
#         "sea_level": 1022,
#         "grnd_level": 865
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.33,
#         "deg": 125,
#         "gust": 2.25
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1721366128,
#     "sys": {
#         "country": "NA",
#         "sunrise": 1721367091,
#         "sunset": 1721406243
#     },
#     "timezone": 7200,
#     "id": 3353540,
#     "name": "Rehoboth",
#     "cod": 200
# }
# here
# Processing Record 3 of Set 1 | chifeng
# {
#     "coord": {
#         "lon": 118.9636,
#         "lat": 42.2683
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 308.9,
#         "feels_like": 307.05,
#         "temp_min": 308.9,
#         "temp_max": 308.9,
#         "pressure": 996,
#         "humidity": 20,
#         "sea_level": 996,
#         "grnd_level": 925
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.55,
#         "deg": 263,
#         "gust": 5.84
#     },
#     "clouds": {
#         "all": 45
#     },
#     "dt": 1721366151,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1721335452,
#         "sunset": 1721388978
#     },
#     "timezone": 28800,
#     "id": 2038067,
#     "name": "Chifeng",
#     "cod": 200
# }
# here
# Processing Record 4 of Set 1 | grytviken
# {
#     "coord": {
#         "lon": -36.5092,
#         "lat": -54.2811
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 271.92,
#         "feels_like": 269,
#         "temp_min": 271.92,
#         "temp_max": 271.92,
#         "pressure": 1004,
#         "humidity": 94,
#         "sea_level": 1004,
#         "grnd_level": 1000
#     },
#     "visibility": 4291,
#     "wind": {
#         "speed": 2.21,
#         "deg": 322,
#         "gust": 3.31
#     },
#     "clouds": {
#         "all": 79
#     },
#     "dt": 1721366174,
#     "sys": {
#         "country": "GS",
#         "sunrise": 1721385134,
#         "sunset": 1721413926
#     },
#     "timezone": -7200,
#     "id": 3426466,
#     "name": "Grytviken",
#     "cod": 200
# }
# here
# Processing Record 5 of Set 1 | port-aux-francais
# {
#     "coord": {
#         "lon": 70.2167,
#         "lat": -49.35
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 273.8,
#         "feels_like": 267.12,
#         "temp_min": 273.8,
#         "temp_max": 273.8,
#         "pressure": 1013,
#         "humidity": 71,
#         "sea_level": 1013,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.55,
#         "deg": 123,
#         "gust": 9.78
#     },
#     "clouds": {
#         "all": 95
#     },
#     "dt": 1721366196,
#     "sys": {
#         "country": "TF",
#         "sunrise": 1721358255,
#         "sunset": 1721389574
#     },
#     "timezone": 18000,
#     "id": 1546102,
#     "name": "Port-aux-Fran\u00e7ais",
#     "cod": 200
# }
# here
# Processing Record 6 of Set 1 | ulsteinvik
# {
#     "coord": {
#         "lon": 5.8487,
#         "lat": 62.3432
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.4,
#         "feels_like": 288.28,
#         "temp_min": 287.03,
#         "temp_max": 288.75,
#         "pressure": 1019,
#         "humidity": 88,
#         "sea_level": 1019,
#         "grnd_level": 1005
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.79,
#         "deg": 154,
#         "gust": 4.47
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1721366219,
#     "sys": {
#         "type": 2,
#         "id": 2002661,
#         "country": "NO",
#         "sunrise": 1721355954,
#         "sunset": 1721422773
#     },
#     "timezone": 7200,
#     "id": 3133349,
#     "name": "Ulsteinvik",
#     "cod": 200
# }
# here
# Processing Record 7 of Set 1 | lagunas
# {
#     "coord": {
#         "lon": -75.6753,
#         "lat": -5.2269
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 294.33,
#         "feels_like": 294.46,
#         "temp_min": 294.33,
#         "temp_max": 294.33,
#         "pressure": 1016,
#         "humidity": 75,
#         "sea_level": 1016,
#         "grnd_level": 1000
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.7,
#         "deg": 292,
#         "gust": 0.73
#     },
#     "clouds": {
#         "all": 18
#     },
#     "dt": 1721366242,
#     "sys": {
#         "country": "PE",
#         "sunrise": 1721387592,
#         "sunset": 1721430268
#     },
#     "timezone": -18000,
#     "id": 3695844,
#     "name": "Lagunas",
#     "cod": 200
# }
# here
# Processing Record 8 of Set 1 | isafjordur
# {
#     "coord": {
#         "lon": -23.124,
#         "lat": 66.0755
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 280.07,
#         "feels_like": 278.48,
#         "temp_min": 280.07,
#         "temp_max": 280.07,
#         "pressure": 1008,
#         "humidity": 96,
#         "sea_level": 1008,
#         "grnd_level": 977
#     },
#     "visibility": 3002,
#     "wind": {
#         "speed": 2.31,
#         "deg": 27,
#         "gust": 2.45
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1721366264,
#     "sys": {
#         "country": "IS",
#         "sunrise": 1721359556,
#         "sunset": 1721433079
#     },
#     "timezone": 0,
#     "id": 3415667,
#     "name": "Isafjordur",
#     "cod": 200
# }
# here
# Processing Record 9 of Set 1 | talnakh
# {
#     "coord": {
#         "lon": 88.3972,
#         "lat": 69.4865
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.25,
#         "feels_like": 286.89,
#         "temp_min": 288.25,
#         "temp_max": 288.25,
#         "pressure": 1007,
#         "humidity": 41,
#         "sea_level": 1007,
#         "grnd_level": 999
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.83,
#         "deg": 19,
#         "gust": 7.52
#     },
#     "clouds": {
#         "all": 2
#     },
#     "dt": 1721366287,
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 25200,
#     "id": 1490256,
#     "name": "Talnakh",
#     "cod": 200
# }
# here
# Processing Record 10 of Set 1 | gondar
# {
#     "coord": {
#         "lon": 37.4667,
#         "lat": 12.6
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.87,
#         "feels_like": 288.66,
#         "temp_min": 288.87,
#         "temp_max": 288.87,
#         "pressure": 1017,
#         "humidity": 83,
#         "sea_level": 1017,
#         "grnd_level": 790
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.07,
#         "deg": 241,
#         "gust": 1.04
#     },
#     "rain": {
#         "1h": 0.2
#     },
#     "clouds": {
#         "all": 93
#     },
#     "dt": 1721366309,
#     "sys": {
#         "country": "ET",
#         "sunrise": 1721358787,
#         "sunset": 1721404762
#     },
#     "timezone": 10800,
#     "id": 336014,
#     "name": "Gonder",
#     "cod": 200
# }
# here
# Processing Record 11 of Set 1 | barra de santo antonio
# {
#     "coord": {
#         "lon": -35.5072,
#         "lat": -9.4047
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 294.75,
#         "feels_like": 295.05,
#         "temp_min": 294.75,
#         "temp_max": 294.75,
#         "pressure": 1018,
#         "humidity": 80,
#         "sea_level": 1018,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.8,
#         "deg": 113,
#         "gust": 6.34
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1721366332,
#     "sys": {
#         "type": 1,
#         "id": 8413,
#         "country": "BR",
#         "sunrise": 1721378337,
#         "sunset": 1721420242
#     },
#     "timezone": -10800,
#     "id": 3406333,
#     "name": "Barra de Santo Ant\u00f4nio",
#     "cod": 200
# }
# here
# Processing Record 12 of Set 1 | camocim
# {
#     "coord": {
#         "lon": -40.8411,
#         "lat": -2.9022
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.05,
#         "feels_like": 296.82,
#         "temp_min": 296.05,
#         "temp_max": 296.05,
#         "pressure": 1015,
#         "humidity": 93,
#         "sea_level": 1015,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.73,
#         "deg": 126,
#         "gust": 11.5
#     },
#     "clouds": {
#         "all": 47
#     },
#     "dt": 1721366355,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1721379020,
#         "sunset": 1721422119
#     },
#     "timezone": -10800,
#     "id": 3403687,
#     "name": "Camocim",
#     "cod": 200
# }
# here
# Processing Record 13 of Set 1 | pisco
# {
#     "coord": {
#         "lon": -76.2167,
#         "lat": -13.7
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.18,
#         "feels_like": 289.95,
#         "temp_min": 289.27,
#         "temp_max": 290.18,
#         "pressure": 1016,
#         "humidity": 77,
#         "sea_level": 1016,
#         "grnd_level": 1012
#     },
#     "visibility": 7000,
#     "wind": {
#         "speed": 1.54,
#         "deg": 80
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1721366377,
#     "sys": {
#         "type": 1,
#         "id": 8691,
#         "country": "PE",
#         "sunrise": 1721388510,
#         "sunset": 1721429610
#     },
#     "timezone": -18000,
#     "id": 3932145,
#     "name": "Pisco",
#     "cod": 200
# }
# here
# Processing Record 14 of Set 1 | margaret river
# {
#     "coord": {
#         "lon": 115.0667,
#         "lat": -33.95
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287.7,
#         "feels_like": 286.67,
#         "temp_min": 287.7,
#         "temp_max": 287.7,
#         "pressure": 1020,
#         "humidity": 56,
#         "sea_level": 1020,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.42,
#         "deg": 264,
#         "gust": 10.09
#     },
#     "clouds": {
#         "all": 84
#     },
#     "dt": 1721366400,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1721344846,
#         "sunset": 1721381454
#     },
#     "timezone": 28800,
#     "id": 2066981,
#     "name": "Margaret River",
#     "cod": 200
# }
# here
# Processing Record 15 of Set 1 | puerto natales
# {
#     "coord": {
#         "lon": -72.4875,
#         "lat": -51.7236
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 277.39,
#         "feels_like": 273.69,
#         "temp_min": 277.39,
#         "temp_max": 277.39,
#         "pressure": 1021,
#         "humidity": 85,
#         "sea_level": 1021,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.7,
#         "deg": 286,
#         "gust": 11.84
#     },
#     "clouds": {
#         "all": 62
#     },
#     "dt": 1721366422,
#     "sys": {
#         "country": "CL",
#         "sunrise": 1721393054,
#         "sunset": 1721423276
#     },
#     "timezone": -10800,
#     "id": 3874958,
#     "name": "Puerto Natales",
#     "cod": 200
# }
# here
# Processing Record 16 of Set 1 | taiohae
# {
#     "cod": "404",
#     "message": "city not found"
# }
# here
# City not found. Skipping...
# Processing Record 17 of Set 1 | rockland
# {
#     "coord": {
#         "lon": -74.0496,
#         "lat": 41.1668
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 292.23,
#         "feels_like": 292.18,
#         "temp_min": 289.78,
#         "temp_max": 294.7,
#         "pressure": 1017,
#         "humidity": 76,
#         "sea_level": 1017,
#         "grnd_level": 999
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.24,
#         "deg": 326,
#         "gust": 4.98
#     },
#     "clouds": {
#         "all": 39
#     },
#     "dt": 1721366468,
#     "sys": {
#         "type": 2,
#         "id": 2020322,
#         "country": "US",
#         "sunrise": 1721382001,
#         "sunset": 1721435079
#     },
#     "timezone": -14400,
#     "id": 5134189,
#     "name": "Rockland",
#     "cod": 200
# }
# here
# Processing Record 18 of Set 1 | lebu
# {
#     "coord": {
#         "lon": -73.65,
#         "lat": -37.6167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 280.21,
#         "feels_like": 275.25,
#         "temp_min": 280.21,
#         "temp_max": 280.21,
#         "pressure": 1027,
#         "humidity": 65,
#         "sea_level": 1027,
#         "grnd_level": 1022
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.94,
#         "deg": 175,
#         "gust": 17.5
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1721366491,
#     "sys": {
#         "country": "CL",
#         "sunrise": 1721390633,
#         "sunset": 1721426255
#     },
#     "timezone": -14400,
#     "id": 3883457,
#     "name": "Lebu",
#     "cod": 200
# }
# here
# Processing Record 19 of Set 1 | tofol
# {
#     "coord": {
#         "lon": 163.0078,
#         "lat": 5.3248
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 303.03,
#         "feels_like": 310.03,
#         "temp_min": 303.03,
#         "temp_max": 303.03,
#         "pressure": 1010,
#         "humidity": 79,
#         "sea_level": 1010,
#         "grnd_level": 1008
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.12,
#         "deg": 60
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1721366513,
#     "sys": {
#         "type": 1,
#         "id": 7888,
#         "country": "FM",
#         "sunrise": 1721329341,
#         "sunset": 1721373946
#     },
#     "timezone": 39600,
#     "id": 2081342,
#     "name": "Tofol",
#     "cod": 200
# }
# here
# Processing Record 20 of Set 1 | bochum
# {
#     "coord": {
#         "lon": 7.2167,
#         "lat": 51.4833
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 291.71,
#         "feels_like": 291.71,
#         "temp_min": 290.36,
#         "temp_max": 293.36,
#         "pressure": 1020,
#         "humidity": 80,
#         "sea_level": 1020,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.19,
#         "deg": 141,
#         "gust": 1.27
#     },
#     "clouds": {
#         "all": 74
#     },
#     "dt": 1721366536,
#     "sys": {
#         "type": 2,
#         "id": 2086125,
#         "country": "DE",
#         "sunrise": 1721360213,
#         "sunset": 1721417857
#     },
#     "timezone": 7200,
#     "id": 2947416,
#     "name": "Bochum",
#     "cod": 200
# }
# here
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          19
# Lat           19
# Lng           19
# Max Temp      19
# Humidity      19
# Cloudiness    19
# Wind Speed    19
# Country       19
# Date          19
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015    295.29        88         100
# 1           rehoboth -23.3167   17.0833    278.82        36           0
# 2            chifeng  42.2683  118.9636    308.90        20          45
# 3          grytviken -54.2811  -36.5092    271.92        94          79
# 4  port-aux-francais -49.3500   70.2167    273.80        71          95
#
#    Wind Speed Country        Date
# 0       10.75      PN  1721366106
# 1        2.33      NA  1721366128
# 2        2.55      CN  1721366151
# 3        2.21      GS  1721366174
# 4        9.55      TF  1721366196

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015    295.29        88         100
# 1                 rehoboth -23.3167   17.0833    278.82        36           0
# 2                  chifeng  42.2683  118.9636    308.90        20          45
# 3                grytviken -54.2811  -36.5092    271.92        94          79
# 4        port-aux-francais -49.3500   70.2167    273.80        71          95
#
#          Wind Speed Country        Date
# City_ID
# 0             10.75      PN  1721366106
# 1              2.33     NaN  1721366128
# 2              2.55      CN  1721366151
# 3              2.21      GS  1721366174
# 4              9.55      TF  1721366196

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    plt.grid(True)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           chifeng  42.2683  118.9636    308.90        20          45
# 5        ulsteinvik  62.3432    5.8487    288.75        88          98
# 7        isafjordur  66.0755  -23.1240    280.07        96         100
# 8           talnakh  69.4865   88.3972    288.25        41           2
# 9            gondar  12.6000   37.4667    288.87        83          93
#
#          Wind Speed Country        Date
# City_ID
# 2              2.55      CN  1721366151
# 5              1.79      NO  1721366219
# 7              2.31      IS  1721366264
# 8              7.83      RU  1721366287
# 9              1.07      ET  1721366309

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015    295.29        88         100
# 1                 rehoboth -23.3167   17.0833    278.82        36           0
# 3                grytviken -54.2811  -36.5092    271.92        94          79
# 4        port-aux-francais -49.3500   70.2167    273.80        71          95
# 6                  lagunas  -5.2269  -75.6753    294.33        75          18
#
#          Wind Speed Country        Date
# City_ID
# 0             10.75      PN  1721366106
# 1              2.33     NaN  1721366128
# 3              2.21      GS  1721366174
# 4              9.55      TF  1721366196
# 6              0.70      PE  1721366242

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-squared is: -0.5051240334141507

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(-55,90))
# Out:
# The r-squared is: 0.8803257619858504

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: -0.10238207054231502

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(-50,15))
# Out:
# The r-squared is: -0.0038244490989133946

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(40,10))
# Out:
# The r-squared is: -0.22768584694819924

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(-50,60))
# Out:
# The r-squared is: -0.29676081147329886

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(40,25))
# Out:
# The r-squared is: 0.2486015548706356

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(-50,20))
# Out:
# The r-squared is: -0.3448678518536726

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
